# %%
import pandas as pd

path = "/Users/yiyi_mac/IDP_Code/Ergebnisse/beo7/Analyse/Run_60hz_FullCalib_mode2_20260429_032542/debug_5_pupil_data_calibrated.csv"
df = pd.read_csv(path)

print("Rows:", len(df))
print("Blink frames:", df["is_blink"].sum())
print("Eyes closed frames:", df["eyes_closed"].sum())
print("Blink events:", df["blink_count"].max())
print("EAR range:", df["avg_ear"].min(), df["avg_ear"].max())
print(df[["frame", "timestamp_ms", "avg_ear", "is_blink", "eyes_closed", "blink_count"]].head(20))
# Out:
# Rows: 10906
# Blink frames: 14
# Eyes closed frames: 64
# Blink events: 14
# EAR range: 0.1131930684019782 0.3415024603890509
#     frame   timestamp_ms   avg_ear  is_blink  eyes_closed  blink_count
# 0    7990  181592.032372  0.305425     False        False            0
# 1    7991  181614.759786  0.311210     False        False            0
# 2    7992  181637.487199  0.292024     False        False            0
# 3    7993  181660.214612  0.310020     False        False            0
# 4    7994  181682.942025  0.309785     False        False            0
# 5    7995  181705.669439  0.311005     False        False            0
# 6    7996  181728.396852  0.318537     False        False            0
# 7    7997  181751.124265  0.315885     False        False            0
# 8    7998  181773.851679  0.300832     False        False            0
# 9    7999  181796.579092  0.312429     False        False            0
# ...
